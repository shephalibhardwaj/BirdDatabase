# %%
import pycountry
import pandas as pd
import numpy as np
import wikipedia

# %%
birds_df = pd.read_excel('Bird.xlsx')
birds_df.head()
# Out:
#    Unnamed: 0                Name            Conservation status   Kingdom  \
# 0           0   Wagler's toucanet    Least Concern (IUCN 3.1)[1]  Animalia
# 1           1    Wahlberg's eagle    Least Concern (IUCN 3.1)[1]  Animalia
# 2           2    Wahnes's parotia  Near Threatened (IUCN 3.1)[1]  Animalia
# 3           3  Waigeo brushturkey       Endangered (IUCN 3.1)[1]  Animalia
# 4           5   Wailing cisticola    Least Concern (IUCN 3.1)[1]  Animalia
#
#      Phylum Class            Order         Family           Genus  \
# 0  Chordata  Aves       Piciformes   Ramphastidae  Aulacorhynchus
# 1  Chordata  Aves  Accipitriformes   Accipitridae      Hieraaetus
# 2  Chordata  Aves    Passeriformes  Paradisaeidae         Parotia
# 3  Chordata  Aves      Galliformes   Megapodiidae      Aepypodius
# 4  Chordata  Aves    Passeriformes   Cisticolidae       Cisticola
#
#         Species                                      Binomial Name  \
# 0    A. wagleri  Aulacorhynchus wagleri(Sturm, JHCF & Sturm, JW...
# 1  H. wahlbergi              Hieraaetus wahlbergi(Sundevall, 1851)
# 2    P. wahnesi                    Parotia wahnesiRothschild, 1906
# 3   A. bruijnii                Aepypodius bruijnii(Oustalet, 1880)
# 4       C. lais            Cisticola lais(Hartlaub & Finsch, 1870)
#
#                                             Synonyms  \
# 0  Aulacorhynchus prasinus wagleri Pteroglossus w...
# 1                   Aquila wahlbergi Sundevall, 1850
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              Summary  \
# 0  Wagler's toucanet (Aulacorhynchus wagleri) is ...
# 1  Wahlberg's eagle (Hieraaetus wahlbergi) is a b...
# 2  Wahnes's parotia (Parotia wahnesi) is a medium...
# 3  The Waigeo brushturkey or Bruijn's brushturkey...
# 4  The wailing cisticola (Cisticola lais) is a sp...
#
#                                           Categories  \
# 0  ['All stub articles', "Articles with 'species'...
# 1  ["Articles with 'species' microformats", 'Arti...
# 2  ['All stub articles', "Articles with 'species'...
# 3  ['Aepypodius', "Articles with 'species' microf...
# 4  ['All stub articles', "Articles with 'species'...
#
#                                           References  \
# 0  ['http://datazone.birdlife.org/species/factshe...
# 1  ['http://heatherlerner.com/pdfs/Lerner.Mindell...
# 2  ['http://www.publish.csiro.au/?act=view_file&f...
# 3  ['http://www.rdb.or.id/detailbird.php?id=26', ...
# 4  ['http://www.hbw.com/node/58619', 'http://data...
#
#                                             Wiki URL  \
# 0  https://en.wikipedia.org/wiki/Wagler%27s_toucanet
# 1   https://en.wikipedia.org/wiki/Wahlberg%27s_eagle
# 2   https://en.wikipedia.org/wiki/Wahnes%27s_parotia
# 3   https://en.wikipedia.org/wiki/Waigeo_brushturkey
# 4    https://en.wikipedia.org/wiki/Wailing_cisticola
#
#                                                Image
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...

# %%
birds_df['Countries'] = np.NaN
birds_df['Habitat'] = np.NaN

# %%
for i in range(0, len(birds_df)):
    name = birds_df.Name[i]
    summary = wikipedia.summary(name)
    birds_df.Countries[i] = findCountry(summary)
    birds_df.Habitat[i] = findHabitat(summary)
# Out:
# <ipython-input-20-63f18dc35a6d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds_df.Countries[i] = findCountry(summary)
# <ipython-input-20-63f18dc35a6d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds_df.Habitat[i] = findHabitat(summary)

# %%
def findCountry(data):
    countries = sorted([country.name for country in pycountry.countries] , key=lambda x: -len(x))
    for country in countries:
        if country.lower() in data.lower():
            return country
    return None

# %%
#habitat
habitats_list = ['forest', 'forests', 'woods', 'woods', 'woodland', 'woodlands', 'bog', 'bogs', 'fen', 'fens', 'marsh', 'marshes', 'swamp', 'swamps', 'wetland', 'grasslands', 'prairie', 'scrubs','shrubs', 'backyards']

# %%
def findHabitat(data):
    for habitat in habitats_list:
        if habitat in data.lower():
            return habitat
    return None

# %%
for i in range(0, len(birds_df)):
    name = birds_df.Name[i]
    summary = wikipedia.summary(name)
    birds_df.Countries[i] = findCountry(summary)
    birds_df.Habitat[i] = findHabitat(summary)
# Out:
# <ipython-input-7-63f18dc35a6d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds_df.Countries[i] = findCountry(summary)
# C:\Users\Sankalp\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-7-63f18dc35a6d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds_df.Habitat[i] = findHabitat(summary)

# %%
birds_df.head(20)
# Out:
#     Unnamed: 0                      Name                  Conservation status  \
# 0            0         Wagler's toucanet          Least Concern (IUCN 3.1)[1]
# 1            1          Wahlberg's eagle          Least Concern (IUCN 3.1)[1]
# 2            2          Wahnes's parotia        Near Threatened (IUCN 3.1)[1]
# 3            3        Waigeo brushturkey             Endangered (IUCN 3.1)[1]
# 4            5         Wailing cisticola          Least Concern (IUCN 3.1)[1]
# 5            7          Wake Island rail         Extinct (1945) (IUCN 3.1)[1]
# 6            8           Wakolo myzomela          Least Concern (IUCN 3.1)[1]
# 7            9         Walden's hornbill  Critically Endangered (IUCN 3.1)[1]
# 8           10    Wallacean cuckooshrike          Least Concern (IUCN 3.1)[1]
# 9           11          Wallacean drongo          Least Concern (IUCN 3.1)[1]
# 10          12        Wallacean whistler          Least Concern (IUCN 3.1)[1]
# 11          13       Wallace's fairywren          Least Concern (IUCN 3.1)[1]
# 12          14      Wallace's fruit dove          Least Concern (IUCN 3.1)[1]
# 13          16      Wallace's hawk-eagle             Vulnerable (IUCN 3.1)[1]
# 14          17  Wallace's owlet-nightjar          Least Concern (IUCN 3.1)[1]
# 15          18       Wallace's scops owl          Least Concern (IUCN 3.1)[1]
# 16          19               Wallcreeper          Least Concern (IUCN 3.1)[1]
# 17          20         Waller's starling          Least Concern (IUCN 3.1)[1]
# 18          21       Wandering albatross             Vulnerable (IUCN 3.1)[1]
# 19          22         Wandering tattler          Least Concern (IUCN 3.1)[1]
#
#      Kingdom    Phylum Class              Order                       Family  \
# 0   Animalia  Chordata  Aves         Piciformes                 Ramphastidae
# 1   Animalia  Chordata  Aves    Accipitriformes                 Accipitridae
# 2   Animalia  Chordata  Aves      Passeriformes                Paradisaeidae
# 3   Animalia  Chordata  Aves        Galliformes                 Megapodiidae
# 4   Animalia  Chordata  Aves      Passeriformes                 Cisticolidae
# 5   Animalia  Chordata  Aves         Gruiformes                     Rallidae
# 6   Animalia  Chordata  Aves      Passeriformes                 Meliphagidae
# 7   Animalia  Chordata  Aves     Bucerotiformes                  Bucerotidae
# 8   Animalia  Chordata  Aves      Passeriformes                Campephagidae
# 9   Animalia  Chordata  Aves      Passeriformes                   Dicruridae
# 10  Animalia  Chordata  Aves      Passeriformes              Pachycephalidae
# 11  Animalia  Chordata  Aves      Passeriformes                    Maluridae
# 12  Animalia  Chordata  Aves      Columbiformes                   Columbidae
# 13  Animalia  Chordata  Aves    Accipitriformes                 Accipitridae
# 14  Animalia  Chordata  Aves    Aegotheliformes                 Aegothelidae
# 15  Animalia  Chordata  Aves       Strigiformes                    Strigidae
# 16  Animalia  Chordata  Aves      Passeriformes  TichodromidaeSwainson, 1827
# 17  Animalia  Chordata  Aves      Passeriformes                    Sturnidae
# 18  Animalia  Chordata  Aves  Procellariiformes                  Diomedeidae
# 19  Animalia  Chordata  Aves    Charadriiformes                 Scolopacidae
#
#                       Genus          Species  \
# 0            Aulacorhynchus       A. wagleri
# 1                Hieraaetus     H. wahlbergi
# 2                   Parotia       P. wahnesi
# 3                Aepypodius      A. bruijnii
# 4                 Cisticola          C. lais
# 5              Hypotaenidia     †H. wakensis
# 6                  Myzomela   M. wakoloensis
# 7           Rhabdotorrhinus       R. waldeni
# 8                  Coracina     C. personata
# 9                  Dicrurus        D. densus
# 10             Pachycephala  P. arctitorquis
# 11   SipodotusMathews, 1928      S. wallacii
# 12               Ptilinopus      P. wallacii
# 13                 Nisaetus         N. nanus
# 14               Aegotheles      A. wallacii
# 15                     Otus     O. silvicola
# 16  TichodromaIlliger, 1811       T. muraria
# 17            Onychognathus       O. walleri
# 18                 Diomedea       D. exulans
# 19                   Tringa        T. incana
#
#                                         Binomial Name  \
# 0   Aulacorhynchus wagleri(Sturm, JHCF & Sturm, JW...
# 1               Hieraaetus wahlbergi(Sundevall, 1851)
# 2                     Parotia wahnesiRothschild, 1906
# 3                 Aepypodius bruijnii(Oustalet, 1880)
# 4             Cisticola lais(Hartlaub & Finsch, 1870)
# 5            †Hypotaenidia wakensis(Rothschild, 1903)
# 6                    Myzomela wakoloensisForbes, 1883
# 7                 Rhabdotorrhinus waldeniSharpe, 1877
# 8                    Coracina personata(Müller, 1843)
# 9                      Dicrurus densusBonaparte, 1850
# 10             Pachycephala arctitorquisSclater, 1883
# 11               Sipodotus wallacii(Gray, G.R., 1862)
# 12                      Ptilinopus wallaciiGray, 1858
# 13                      Nisaetus nanus(Wallace, 1868)
# 14                      Aegotheles wallaciiGray, 1859
# 15                      Otus silvicola(Wallace, 1864)
# 16                 Tichodroma muraria(Linnaeus, 1766)
# 17               Onychognathus walleri(Shelley, 1880)
# 18                  Diomedea exulansLinnaeus, 1758[2]
# 19                        Tringa incana(Gmelin, 1789)
#
#                                              Synonyms  \
# 0   Aulacorhynchus prasinus wagleri Pteroglossus w...
# 1                    Aquila wahlbergi Sundevall, 1850
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5              Hypotaenidia wakensis Rothschild, 1903
# 6                                                 NaN
# 7          Aceros leucocephalus waldeniAceros waldeni
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Todopsis wallacii Gray, G.R., 1862 Todopsis co...
# 12                                                NaN
# 13                      Spizaetus nanus[3] (protonym)
# 14                                                NaN
# 15                                                NaN
# 16                     Certhia muraria Linnaeus, 1766
# 17                                                NaN
# 18                                                NaN
# 19          Heteractitis incanus Heteroscelus incanus
#
#                                               Summary  \
# 0   Wagler's toucanet (Aulacorhynchus wagleri) is ...
# 1   Wahlberg's eagle (Hieraaetus wahlbergi) is a b...
# 2   Wahnes's parotia (Parotia wahnesi) is a medium...
# 3   The Waigeo brushturkey or Bruijn's brushturkey...
# 4   The wailing cisticola (Cisticola lais) is a sp...
# 5   The extinct Wake Island rail (Hypotaenidia wak...
# 6   The Wakolo myzomela (Myzomela wakoloensis) is ...
# 7   Walden's hornbill (Rhabdotorrhinus waldeni) lo...
# 8   The Wallacean cuckooshrike (Coracina personata...
# 9   The Wallacean drongo or Greater Wallacean dron...
# 10  The Wallacean whistler (Pachycephala arctitorq...
# 11  Wallace's fairywren (Sipodotus wallacii) is a ...
# 12  Wallace's fruit dove (Ptilinopus wallacii) is ...
# 13  Wallace's hawk-eagle (Nisaetus nanus) is a spe...
# 14  Owlet-nightjars are small crepuscular birds re...
# 15  Scops owls are typical owls in family Strigida...
# 16  The wallcreeper (Tichodroma muraria) is a smal...
# 17  Waller's starling (Onychognathus walleri) is a...
# 18  The wandering albatross, snowy albatross, whit...
# 19  The wandering tattler (Tringa incana; formerly...
#
#                                            Categories  \
# 0   ['All stub articles', "Articles with 'species'...
# 1   ["Articles with 'species' microformats", 'Arti...
# 2   ['All stub articles', "Articles with 'species'...
# 3   ['Aepypodius', "Articles with 'species' microf...
# 4   ['All stub articles', "Articles with 'species'...
# 5   ['All articles lacking in-text citations', 'Al...
# 6   ['All stub articles', "Articles with 'species'...
# 7   ['All stub articles', "Articles with 'species'...
# 8   ['All stub articles', "Articles with 'species'...
# 9   ['All stub articles', "Articles with 'species'...
# 10  ['All stub articles', "Articles with 'species'...
# 11  ["Articles with 'species' microformats", 'Arti...
# 12  ["Articles with 'species' microformats", 'Arti...
# 13  ['Accipitriformes stubs', 'All stub articles',...
# 14  ['Aegotheliformes', 'All pages needing factual...
# 15  ['All articles needing additional references',...
# 16  ["Articles with 'species' microformats", 'Arti...
# 17  ['All stub articles', "Articles with 'species'...
# 18  ['Articles containing video clips', "Articles ...
# 19  ['All articles with unsourced statements', 'Ar...
#
#                                            References  \
# 0   ['http://datazone.birdlife.org/species/factshe...
# 1   ['http://heatherlerner.com/pdfs/Lerner.Mindell...
# 2   ['http://www.publish.csiro.au/?act=view_file&f...
# 3   ['http://www.rdb.or.id/detailbird.php?id=26', ...
# 4   ['http://www.hbw.com/node/58619', 'http://data...
# 5   ['http://www.botany.hawaii.edu/faculty/duffy/A...
# 6   ['http://datazone.birdlife.org/species/factshe...
# 7   ['http://datazone.birdlife.org/species/factshe...
# 8   ['http://datazone.birdlife.org/species/factshe...
# 9   ['http://ibc.lynxeds.com/species/wallacean-dro...
# 10  ['http://datazone.birdlife.org/species/factshe...
# 11  ['http://animaldiversity.ummz.umich.edu/site/r...
# 12  ['http://datazone.birdlife.org/species/factshe...
# 13  ['http://www.vogelwarte.uni-greifswald.de/pdf/...
# 14  ['http://www.senckenberg.de/files/content/fors...
# 15  ['http://www.ornithomedia.com/breves/petit-duc...
# 16  ['http://www.hbw.com/species/wallcreeper-ticho...
# 17  ['http://datazone.birdlife.org/species/factshe...
# 18  ['http://birdlife.org.au/bird-profile/wanderin...
# 19  ['http://jboyd.net/Taxo/List9a.html', 'http://...
#
#                                              Wiki URL  \
# 0   https://en.wikipedia.org/wiki/Wagler%27s_toucanet
# 1    https://en.wikipedia.org/wiki/Wahlberg%27s_eagle
# 2    https://en.wikipedia.org/wiki/Wahnes%27s_parotia
# 3    https://en.wikipedia.org/wiki/Waigeo_brushturkey
# 4     https://en.wikipedia.org/wiki/Wailing_cisticola
# 5      https://en.wikipedia.org/wiki/Wake_Island_rail
# 6       https://en.wikipedia.org/wiki/Wakolo_myzomela
# 7   https://en.wikipedia.org/wiki/Walden%27s_hornbill
# 8   https://en.wikipedia.org/wiki/Wallacean_cuckoo...
# 9      https://en.wikipedia.org/wiki/Wallacean_drongo
# 10   https://en.wikipedia.org/wiki/Wallacean_whistler
# 11  https://en.wikipedia.org/wiki/Wallace%27s_fair...
# 12  https://en.wikipedia.org/wiki/Wallace%27s_frui...
# 13  https://en.wikipedia.org/wiki/Wallace%27s_hawk...
# 14       https://en.wikipedia.org/wiki/Owlet-nightjar
# 15            https://en.wikipedia.org/wiki/Scops_owl
# 16          https://en.wikipedia.org/wiki/Wallcreeper
# 17  https://en.wikipedia.org/wiki/Waller%27s_starling
# 18  https://en.wikipedia.org/wiki/Wandering_albatross
# 19    https://en.wikipedia.org/wiki/Wandering_tattler
#
#                                                 Image          Countries  \
# 0   https://upload.wikimedia.org/wikipedia/commons...             Mexico
# 1   https://upload.wikimedia.org/wikipedia/commons...               None
# 2   https://upload.wikimedia.org/wikipedia/commons...   Papua New Guinea
# 3   https://upload.wikimedia.org/wikipedia/commons...          Indonesia
# 4   https://upload.wikimedia.org/wikipedia/commons...       South Africa
# 5   https://upload.wikimedia.org/wikipedia/commons...               None
# 6   https://upload.wikimedia.org/wikipedia/commons...          Indonesia
# 7   https://upload.wikimedia.org/wikipedia/commons...        Philippines
# 8   https://upload.wikimedia.org/wikipedia/commons...          Indonesia
# 9   https://upload.wikimedia.org/wikipedia/commons...          Indonesia
# 10  https://upload.wikimedia.org/wikipedia/commons...               None
# 11  https://upload.wikimedia.org/wikipedia/commons...             Guinea
# 12  https://upload.wikimedia.org/wikipedia/commons...          Indonesia
# 13  https://upload.wikimedia.org/wikipedia/commons...               None
# 14  https://upload.wikimedia.org/wikipedia/commons...      New Caledonia
# 15  https://upload.wikimedia.org/wikipedia/commons...          Indonesia
# 16  https://upload.wikimedia.org/wikipedia/commons...              China
# 17  https://upload.wikimedia.org/wikipedia/commons...  Equatorial Guinea
# 18  https://upload.wikimedia.org/wikipedia/commons...               None
# 19  https://upload.wikimedia.org/wikipedia/commons...          Australia
#
#      Habitat
# 0     forest
# 1   woodland
# 2     forest
# 3     forest
# 4       None
# 5       None
# 6     forest
# 7     forest
# 8     forest
# 9     forest
# 10    forest
# 11    forest
# 12    forest
# 13    forest
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None

# %%
#Exporting data to Excel
#Give File name here
file_name = 'bird_W_complete.xlsx'
  
# writing to excel
birds_df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
